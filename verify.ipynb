# %% [markdown]
# # TremorLens — one-click verification
# **Run All** reproduces the 0.31% frequency-recovery proof against synthetic ground truth (the harness renders its own physics-true test videos — no data downloads).
# Takes ~10 min on the free CPU runtime. Expected final line: `RESULT: PASS ✅`

# %%
# !git clone -q https://github.com/mightbeanshuu/tremorlens.git
# %cd tremorlens

# %%
# %pip install -q -r requirements.txt  # all preinstalled on Colab; no-ops in seconds

# %%
# !python src/run_verify.py

# %% [markdown]
# ## What you just reproduced
# Recorded output from the same commands (local run, 2 Aug 2026):
# ```
# == TremorLens verification (capture-realistic test set) ==
# test_healthy_motor     GT 7.30 Hz ->  7.277 Hz  err 0.31%  [OK ]
# test_healthy_take2     GT 7.30 Hz ->  7.278 Hz  err 0.31%  [OK ]
# test_healthy_tap       GT 7.30 Hz ->  7.251 Hz  err 0.68%  [OK ]
# test_damaged_motor     GT 6.20 Hz ->  6.222 Hz  err 0.36%  [OK ]
# test_damaged_tap       GT 6.20 Hz ->  6.125 Hz  err 1.20%  [OK ]
# healthy re-take: SHS 100.0  HEALTHY
# damaged twin  : SHS  28.5  ALERT
# RESULT: PASS ✅
# ```
# GT = ground-truth physics of the rendered rig; recovered f₁ within 0.31–1.2%. The damaged twin alerts, the healthy re-take does not.
# Live demo: [tremorlens-live.vercel.app](https://tremorlens-live.vercel.app)
